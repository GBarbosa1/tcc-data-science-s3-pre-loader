# %%
import boto3
import os
import pandas as pd
import yfinance as yf
from dotenv import load_dotenv
from botocore.exceptions import NoCredentialsError

# %% [markdown]
# Configurations

# %%
load_dotenv("src/enviroment/.env")

aws_access_key = os.getenv("AWS_ACCESS_KEY_ID")
aws_secret_key = os.getenv("AWS_SECRET_ACCESS_KEY")
aws_region = os.getenv("AWS_REGION")

bucket_name = "silver-finance-data"

# %%
session = boto3.Session(
    aws_access_key_id = os.environ["AWS_ACCESS_KEY_ID"],
    aws_secret_access_key = os.environ["AWS_SECRET_ACCESS_KEY"],
    region_name = "us-east-1"
)
s3 = session.resource("s3")

# %% [markdown]
# Functions

# %%
def dump_json_yfinance(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date)
    return data

# %%
ticker = '^BVSP'
start_date = '1900-01-01'
end_date = '2024-09-01'
data = dump_json_yfinance(ticker, start_date, end_date)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price               Close           High            Low           Open  \
# Ticker              ^BVSP          ^BVSP          ^BVSP          ^BVSP
# Date
# 1993-04-27      24.500000      25.400000      24.500000      24.799999
# 1993-04-28      24.299999      24.600000      23.700001      24.500000
# 1993-04-29      23.700001      24.799999      23.700001      24.299999
# 1993-04-30      24.100000      24.200001      23.700001      23.700001
# 1993-05-03      24.100000      24.400000      23.799999      24.100000
# ...                   ...            ...            ...            ...
# 2024-08-26  136889.000000  137013.000000  135596.000000  135608.000000
# 2024-08-27  136776.000000  137213.000000  136664.000000  136888.000000
# 2024-08-28  137344.000000  137469.000000  135746.000000  136776.000000
# 2024-08-29  136041.000000  137370.000000  135858.000000  137349.000000
# 2024-08-30  136004.000000  136139.000000  134910.000000  136041.000000
#
# Price         Volume
# Ticker         ^BVSP
# Date
# 1993-04-27         0
# 1993-04-28         0
# 1993-04-29         0
# 1993-04-30         0
# 1993-05-03         0
# ...              ...
# 2024-08-26   7560000
# 2024-08-27   6745900
# 2024-08-28   7457100
# 2024-08-29   8385100
# 2024-08-30  18397900
#
# [7762 rows x 5 columns]
